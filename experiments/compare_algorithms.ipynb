# %% [markdown]
# # Compare Thermal Control Algorithms
#
# This notebook loads the CSV results produced by `run_all_algorithms.py` and recreates the figures interactively. Run the script first, then execute the cells below to visualize metrics and perform custom analysis.
